# %%
import numpy as np
import matplotlib.pyplot as plt
a = 10
f = np.linspace(0, 7, 100)
r = []
r = a * np.sin(f[np.where(f!=0)]) / f[np.where(f!=0)]
x = r * np.cos(f[np.where(f!=0)])
y = r * np.sin(f[np.where(f!=0)])
plt.plot(x,y)
plt.grid()
plt.show()
